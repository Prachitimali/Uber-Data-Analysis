# %%
import pandas as pd
import numpy as nm 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading the dataset
data = pd.read_csv("UberDataset.csv")
data
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#cloning the dataset
clone_data = data.copy()

# %%
# Check for missing values
print(clone_data.isnull().sum())
# Out:
# START_DATE    0
# END_DATE      0
# CATEGORY      0
# START         0
# STOP          0
# MILES         0
# PURPOSE       0
# dtype: int64

# %%
# Handle missing values 
clone_data.fillna(0, inplace=True)

# %%
# Check data types
print(clone_data.dtypes)
clone_data
# Out:
# START_DATE    category
# END_DATE        object
# CATEGORY        object
# START           object
# STOP            object
# MILES          float64
# PURPOSE         object
# dtype: object
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# ...

# %%
# Check for duplicates
duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

# Remove duplicates
data.drop_duplicates(inplace=True)
# Out:
# Number of duplicate rows: 0

# %%
# Convert MILES to numeric
clone_data['MILES'] = pd.to_numeric(clone_data['MILES'], errors='coerce')

# Display updated types
print(clone_data.dtypes)
# Out:
# START_DATE    category
# END_DATE        object
# CATEGORY        object
# START           object
# STOP            object
# MILES          float64
# PURPOSE         object
# dtype: object

# %%
# Remove outliers using the IQR method
numerical_columns = clone_data.select_dtypes(include=['int64', 'float64']).columns
for column in numerical_columns:
    Q1 = clone_data[column].quantile(0.25)
    Q3 = clone_data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter out outliers
    clone_data = clone_data[(clone_data[column] >= lower_bound) & (clone_data[column] <= upper_bound)]
